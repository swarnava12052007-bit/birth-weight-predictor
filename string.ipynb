# %%
#task 1
tagline = "Atomberg Fans – Save Energy, Save Money"
print(tagline)

slogan = 'Designed for the Future'
print(slogan)

description = """Atomberg fans use BLDC motor technology.
They consume only 28W at the highest speed.
Ideal for energy-conscious households."""
print(description)
# Out:
# Atomberg Fans – Save Energy, Save Money
# Designed for the Future
# Atomberg fans use BLDC motor technology.
# They consume only 28W at the highest speed.
# Ideal for energy-conscious households.

# %%
#task 2
product_name = "Atomberg Renesa+"
print(len(product_name))

import sys
short_name = "Renesa+"
long_description = "Atomberg Renesa+ is a BLDC fan with smart remote, consumes 28W at full speed."
print(sys.getsizeof(short_name))       
print(sys.getsizeof(long_description))
# Out:
# 16
# 48
# 118

# %%
#task 3
text = "Atomberg Renesa+ uses BLDC motor technology."
print("BLDC" in text)

Features = "Smart Remote, 5-Star Energy Rating, LED Indicators"
print("Smart Remote" in Features)

rating = "Our fans have a 5-star rating for maximum efficiency."
print("5-star rating" in rating) 

input = "Atomberg fans ensure Energy Saving of up to 65% compared to regular fans."
if "Energy Saving" in input:
    print ("Energy Saving feature")
else:
    print("feature not found")
# Out:
# True
# True
# True
# Energy Saving feature

# %%
#task 4
input = "Atomberg Efficio"
print(input[0])
print(input[-1])

input = "Renesa Smart+"
print(input[3])
# Out:
# A
# o
# e

# %%
#task 5
input = "REN12345XYZ"
print(input[-3:])

input = "REN12345XYZ"
print(input[2], input[-9], input[2] == input[-9])
# Out:
# XYZ
# N N True

# %%
#task 6
input = "Atomberg Renesa Smart+"
print(input[9:16])

input = "Atomberg Renesa Smart+"
print(input[-6:])

input = "Warranty: 2 Years on Motor"
print(input[10:17])

input = "Atomberg Renesa Smart+" #empty string from start > end
print(input[10:3])
# Out:
# Renesa
# Smart+
# 2 Years

# %%
#task 7
input = "Atomberg Renesa"
print(input[::2])

input = "Energy Efficient"
print(input[::2])

input = "Energy Efficient"
print(input[::-2])
# Out:
# Aobr eea
# Eeg fiin
# tecfEyrn

# %%
#task 8
input = "Atomberg"
print(input[::-1])

line = "Atomberg Renesa+"
model_part = line.split(" ", 1)[1]
print(model_part[::-1])

input = "High Speed Motor"
print(input[::-1])
# Out:
# grebmotA
# +aseneR
# rotoM deepS hgiH

# %%
#task 9
product_review = "This fan is extremely energy efficient and runs smoothly even at low voltages. The remote works perfectly."
print(product_review[:100])

ticket = "TICKET-20250809"
print(ticket[7:18])

input_string = "Model: Renesa+, Color: White, Speed: 5"
print(input_string.split(':')[-1])

qr_code_data = "ATB-RNS-5STAR-2025"
print(qr_code_data.split('-')[-1])
# Out:
# This fan is extremely energy efficient and runs smoothly even at low voltages. The remote works perf
# 20250809
#  5
# 2025

# %%
#NEW TASKS OF STRING METHODS

# %%
#task 1
s = "ATOMBERG RENESA+ USES BLDC MOTOR"
s_lower = s.lower()
print(s_lower)

product = "Atomberg Efficio – Best-Selling Ceiling Fan"
product_lower = product.lower()
print(len(product_lower))
# Out:
# atomberg renesa+ uses bldc motor
# 43

# %%
#task 2
s = "Atomberg fans save energy"
s_upper = s.upper()
print(s_upper)

feature = "Smart remote with boost mode"
feature_upper = feature.upper()
print(feature_upper)
print("BOOST" in feature_upper)
# Out:
# ATOMBERG FANS SAVE ENERGY
# SMART REMOTE WITH BOOST MODE
# True

# %%
#task 3
tag = "bldc motor for energy savings"
tag_title = tag.title()
print(tag_title)

headline = "renesa smart+ ceiling fan with led indicators"
headline_title = headline.title()
print(headline_title)
# Out:
# Bldc Motor For Energy Savings
# Renesa Smart+ Ceiling Fan With Led Indicators

# %%
#task 4
line = "atomberg renesa+ is highly efficient"
line_cap = line.capitalize()
print(line_cap)

msg = "ENERGY SAVING UP TO 65%"
msg_cap = msg.capitalize()
print(msg_cap)
# Out:
# Atomberg renesa+ is highly efficient
# Energy saving up to 65%

# %%
#task 5
note = "Atomberg RENESA+ Has a SMART Remote" 
note_swapped = note.swapcase()
print(note_swapped)

cta = "BUY Now and Save ENERGY"
cta_swapped = cta.swapcase()
print(cta_swapped)
# Out:
# aTOMBERG renesa+ hAS A smart rEMOTE
# buy nOW AND sAVE energy

# %%
#task 6
spec = "Atomberg Renesa+ uses BLDC motor and consumes 28W at top speed"
i_bldc = spec.find("BLDC")
print(i_bldc)

spec = "Atomberg Renesa+ uses BLDC motor and consumes 28W at top speed"
i_wifi = spec.find("WIFI")
print(i_wifi)

desc = "Energy efficient, energy saving, ENERGY star-like performance"
i_energy = desc.find("energy")
print(i_energy)
# Out:
# 22
# -1
# 18

# %%
#task 7
line = "Smart remote, smart scheduling, SMART comfort"
last_smart = line.rfind("smart")
print(last_smart)

warranty = "Warranty: 2 Years on Motor. Extended warranty available: 3 Years."
year_idx = warranty.rfind("Years")
print(year_idx)
# Out:
# 14
# 59

# %%
#task 8
brochure = "Atomberg Efficio: 5-star rating, BLDC motor, remote control"
idx_bldc = brochure.index("BLDC")
print(idx_bldc)

brochure = "Atomberg Efficio: 5-star rating, BLDC motor, remote control"
try:
    brochure.index("WiFi")
    print("wifi found")

except ValueError:
    print("wifi not found")
# Out:
# 33
# wifi not found

# %%
#task 9
review = "Quiet fan, quiet operation, truly quiet even at top speed"
c_quiet = review.count("quiet")
print(c_quiet)

mix = "BLDC, bldc, Bldc motors are efficient"
c_case_sensitive = mix.count("BLDC")
print(c_case_sensitive)

c_case_insensitive = mix.lower().count("bldc")
print(c_case_insensitive)
# Out:
# 2
# 1
# 3

# %%
#task 10
txt = "Renesa fan uses induction motor"
txt_fixed = txt.replace("induction", "BLDC")
print(txt_fixed)

service = "Call 1800-000-ATOM for service. 1800-000-ATOM is toll-free."
service_updated = service.replace("1800-000-ATOM", "1800-111-ATOM", 1)
print(service_updated)

pitch = "smart remote, Smart remote, SMART remote"
pitch_norm = pitch.lower().replace("smart remote", "smart RF remote")
print(pitch_norm)
# Out:
# Renesa fan uses BLDC motor
# Call 1800-111-ATOM for service. 1800-000-ATOM is toll-free.
# smart RF remote, smart RF remote, smart RF remote

# %%
#task 11
s = "Model Renesa+ color White speed 5"
s_model = s.split()
print(s_model)

detail = "Model: Renesa+, Color: White, Speed: 5, Power: 28W"
items = detail.split(",")
print(items)

pair = "Warranty: 2 Years on Motor"
kv = pair.split(",", maxsplit=1)
print(kv)
# Out:
# ['Model', 'Renesa+', 'color', 'White', 'speed', '5']
# ['Model: Renesa+', ' Color: White', ' Speed: 5', ' Power: 28W']
# ['Warranty: 2 Years on Motor']

# %%
#task 12
words = ["Atomberg", "Renesa+", "BLDC", "fan"]
line = " ".join(words)
print(line)

features = ["Smart Remote", "LED Indicators", "5-Star Rating"]
features_csv = ",".join(features)
print(features_csv)

codes = ["ATB", "RNS", "5STAR", "2025"]
qr_like = "|".join(codes)
print(qr_like)
# Out:
# Atomberg Renesa+ BLDC fan
# Smart Remote,LED Indicators,5-Star Rating
# ATB|RNS|5STAR|2025

# %%
#more tasks
feedback = "The Remote is SMART and the fan is Smart but not a smart-home device"
smart_count = feedback.lower().count("smart")
print(smart_count)

ad = "Check Renesa+, Efficio, and Renesa+ again for discounts"
start = ad.rfind("Renesa+")
last_mention = ad[start:] if start != -1 else ""
print(last_mention)

raw = "smart remote; bldc motor; 5-star rating"
features_line = " | ".join(raw.title().split("; "))
print(features_line)

text = "Atomberg Renesa+ comes with a remote and BLDC motor"
try:
    text.index("Wifi")
    print("Wifi found")

except ValueError:
    print("Wifi not found")
# Out:
# 3
# Renesa+ again for discounts
# Smart Remote | Bldc Motor | 5-Star Rating
# Wifi not found
