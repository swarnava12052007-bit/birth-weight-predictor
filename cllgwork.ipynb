# %%
print("16")
# Out:
# 17
# type

# %%
s = 9
print(type(s))
# Out:
# <class 'int'>

# %%
s1 = 15.6
print(type(s1))
# Out:
# <class 'float'>

# %%
s2 = "Swarn" 
print(type(s2))
# Out:
# <class 'str'>

# %%
print("Swarnava")
# Out:
# Swarnava

# %%
name = str(input("enter ur name"))
print(name)
# Out:
# swarn

# %%
principal = int(input("enter your principal amount"))
rate = int(input("enter the rate"))
time = int(input("enter your time required"))

simple_interest = (principal*rate*time)/100
print("simple interest =", simple_interest)

compound_interest = principal * (1 + rate /100) ** time - principal
print("compound interest = ", compound_interest)
# Out:
# simple interest = 1200.0
# compound interest =  1218.0

# %%
text = "Swarnava Das"
print(len(text))
text2 = "python for bio"
print(len(text2))
# Out:
# 12
# 14

# %%
text2 = "python for bio"
words = text2.split()
print(words)
# Out:
# ['python', 'for', 'bio']

# %%
text3 = ["python", "for", "biology"]
word = text3.join()
print(word)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 text3 = ["python", "for", "biology"]
# ----> 2 word = text3.join()
#       3 print(word)
#
# AttributeError: 'list' object has no attribute 'join'

# %%
text5 = "Swarnava"
print(text5[0])
print(text5[-1])
# Out:
# S
# a

# %%
text8= "bioinformatics"
print(text8[3:9])
print(text8[5:8])
# Out:
# inform
# for

# %%
text10 = int(input("length"))
text11 = int(input("breadth"))
area = text10*text11
print("the area of the rectanle is:", area)
# Out:
# the area of the rectanle is: 32

# %%
def print_my_name(name):
    for i in range(10): 
      print(name)

# %%
print_my_name("Swarnava")
# Out:
# Swarnava
# Swarnava
# Swarnava
# Swarnava
# Swarnava
# Swarnava
# Swarnava
# Swarnava
# Swarnava
# Swarnava

# %%
def class9():
    
    a = int(input("enter 1st Number"))
    b = int(input("enter 2nd Number"))
    return a+b

# %%
class9()
# Out:
# 25

# %%
def class5():
    a = int(input("enter 1st Number"))
    b = int(input("enter 2nd Number"))
    c = int(input("enter 3rd Number"))
    return a*b*c

# %%
class5()
# Out:
# 336

# %%
def class2():
    a = int(input("enter number"))
    if a%2==0:
        print("even")
    else:
        print("odd")

# %%
class2()
# Out:
# even

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

num = int(input("Enter a number: "))
if is_prime(num):
    print(f"{num} is prime")
else:
    print(f"{num} is not prime")
# Out:
# 35 is not prime

# %%
my_list = [3, 5, 2, 8, 4, 9, 1, 7]
print(my_list)

for i in range(0, 8):
    print(i)

my_list.append(10)
print(my_list)

my_list.remove(4)
print(my_list)

print(len(my_list))
# Out:
# [3, 5, 2, 8, 4, 9, 1, 7]
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# [3, 5, 2, 8, 4, 9, 1, 7, 10]
# [3, 5, 2, 8, 9, 1, 7, 10]
# 8

# %%
i = 0
while i < len(my_list):
    print(my_list[i])
    i += 1
# Out:
# 3
# 5
# 2
# 8
# 9
# 1
# 7
# 10

# %%
max_val = my_list[0]
for num in my_list:
    if num > max_val:
        max_val = num
print("Maximum element:", max_val)
# Out:
# Maximum element: 10

# %%
if 5 in my_list:
    print("5 is present in the list")
else:
    print("5 is not present in the list")
# Out:
# 5 is present in the list

# %%
max_element = max(my_list)
print(max_element)

min_element = min(my_list)
print(min_element)
# Out:
# 10
# 1

# %%
dict1 = {"name": "Swarnava", "age": 20, "city": "Kolkata", "course": "Python for Bioinformatics"}
dict1(age)

# %%
#to perform operations in lists and dictionary
#to analyse dna sequences and calculating gc content
#

# %%
def calculate_gc_content(dna_sequence):
    dna_sequence = dna_sequence.upper()
    g_count = dna_sequence.count('G')
    c_count = dna_sequence.count('C')
    
    if len(dna_sequence) == 0:
        return 0
        
    gc_content = (g_count + c_count) / len(dna_sequence) * 100
    return gc_content

# %%
# %pip install flask
# Out:
# ...
#   Using cached flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# ...
# Using cached flask-3.1.3-py3-none-any.whl (103 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached click-8.3.3-py3-none-any.whl (110 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached werkzeug-3.1.8-py3-none-any.whl (226 kB)
# ...
#
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    -------- ------------------------------- 1/5 [itsdangerous]
#    ---------------- ----------------------- 2/5 [click]
#    -------------------------------- ------- 4/5 [flask]
#    -------------------------------- ------- 4/5 [flask]
# ...

# %%
from flask import Flask
app = Flask(__name__)

@app.route("/")
def hello():
    return "<h1>Success! Flask is running on my computer!</h1>"

if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\User\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:3709: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
