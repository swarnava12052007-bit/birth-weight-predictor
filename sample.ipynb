# %%
input1 = 10
input2 = 20
result = (input1 + input2)*2
print(f"the result would be {result}")
# Out:
# the result would be 60

# %%
print(5>8)
# Out:
# False

# %%
print("S" in "Swarnava")
# Out:
# True

# %%
x = 8
print(x>5 and x<10)
# Out:
# True

# %%
state ="delhi"
if state == "up":
    print("i am from up")
elif state == "wb":
    print("i am from wb")
else:
    print("i am from different state")
# Out:
# i am from different state

# %%
for i in range(10):
    print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#taking input from the user

input1 = input()
input2 = input()
print(input1 + input2)
# Out:
# 672

# %%
number1 = int(input("eneter your number 1"))
number2 = int(input("eneter your number 2"))
result = (number1 + number2)
print(result)
# Out:
# 300

# %%
item, qnty = input("enter item name and quantity")
print()

# %%
# Amazon Logistics – Warehouse Entry Log
employee_name = input("Enter your name: ")
shift_time = input("Enter your shift time (e.g., 9AM–6PM): ")
section = input("Enter warehouse section: ")

print(f"Log recorded for {employee_name} in Section {section} during {shift_time}.")
# Out:
# Log recorded for swarnava das in Section aws during 10-5.

# %%
# Flipkart – Customer Order Capture (Single Product)

product_name = input("Enter product name: ")
quantity = input("Enter quantity ordered: ")
customer = input("Enter customer name: ")

print(f"{quantity} unit(s) of {product_name} ordered by {customer}.")
# Out:
# 1 unit(s) of laptop ordered by swarnava das.

# %%
customer_name = input("Enter full name: ")
number_of_guests = input("enter number")
preferred_time_slot = input("Enter your shift time (e.g., 9AM–6PM): ")

print(f" {customer_name} with {number_of_guests}  members during {preferred_time_slot}.")
# Out:
#  swarnava with 12  members during 9-4.

# %%
dish_name = input("Enter name: ")
cuisine_type = input("enter cuisine")
preparation_time_in_minutes = input("enter number")

print(f" {dish_name} of this {cuisine_type}  would be prepared in {preparation_time_in_minutes}.")
# Out:
#  biriyani of this indian  would be prepared in 20.

# %%
table_number = input("Enter number: ")
dish_ordered = input("enter dish")
quantity = input("enter number")

print(f" {table_number} is to be served with {dish_ordered}  in {quantity} amount.")
# Out:
#  12 is to be served with biriyani  in 2 amount.

# %%
full_name = input("Enter name")
rating_out_of_5 = input("enter number >=5")
feedback = input("enter feedback")

print(f" {full_name} has given {rating_out_of_5} rating along with feedback: {feedback}. ")
# Out:
#  Swarnava has given 5 rating along with feedback: very good.

# %%
today_special_dish = input("Enter dish name")
discount_percentage = input("enter number")
applicable_time_slot = input("enter time  slot")

print(f" {today_special_dish} has been given {discount_percentage} discount during {applicable_time_slot}. ")
# Out:
#  chili fish has been given 20% discount during 9am-5pm.

# %%
rating = int(input("enter rating"))
if rating == 5:
    print("excellent")
elif rating == 4:
    print("good")
elif rating == 3:
    print("average")
else:
    print("to be improved")
# Out:
# to be improved

# %%
temperature = int(input("enter temperature"))
if temperature < 10:
    print("too cold")
if temperature < 15:
    print("cold")
# Out:
# cold

# %%
country = str(input("enter country name"))
if country == "india":
    print("you are indian")
elif country == "australia":
    print("you are australian")
else:
    print("other country")
# Out:
# you are indian

# %%
#task 1
course_completion = int(input("enter your course commpletion percentage"))
if course_completion >= 80:
    print("u are eligible for ai boot camp")
else:
    print("u are not eligible for ai bootcamp")
# Out:
# u are eligible for ai boot camp

# %%
#task 2
number_of_quizes_attempted = int(input("number of quizes completed"))
if number_of_quizes_attempted == 10:
    print("certificate will be issued")
else:
    print("complete all 10 quizes to get the certificate")
# Out:
# certificate will be issued

# %%
#task 3
preferred_time = input("Enter preferred time (Morning, Afternoon, or Evening): ")

if preferred_time == "Morning":
  print("Allocated to 8AM–10AM Batch")
elif preferred_time == "Afternoon":
  print("Allocated to 1PM–3PM Batch")
elif preferred_time == "Evening":
  print("Allocated to 6PM–8PM Batch")
else:
  print("Invalid time preference")
# Out:
# Allocated to 8AM–10AM Batch

# %%
#task 4
final_score = int(input("enter the score (between 70-100): "))
if final_score >= 90:
    print("eligible for internship and placements")
elif 70 <= final_score <= 90:
    print("eligible for internships only")
else:
    print("not eligible")
# Out:
# eligible for internships only

# %%
#task 5 
user_role = input("Enter your user role (Student, Professional, or Institution): ")

if user_role == "Student":
  print("Course price: ₹499")
elif user_role == "Professional":
  print("Course price: ₹999")
elif user_role == "Institution":
  print("Course price: ₹4999")
else:
  print("Invalid user role")
# Out:
# Course price: ₹499

# %%
count = 1
while count <= 50:
    print("Installed grass roll number:", count)
    count += 1
# Out:
# Installed grass roll number: 1
# Installed grass roll number: 2
# Installed grass roll number: 3
# Installed grass roll number: 4
# Installed grass roll number: 5
# Installed grass roll number: 6
# Installed grass roll number: 7
# Installed grass roll number: 8
# Installed grass roll number: 9
# Installed grass roll number: 10
# Installed grass roll number: 11
# Installed grass roll number: 12
# Installed grass roll number: 13
# Installed grass roll number: 14
# Installed grass roll number: 15
# Installed grass roll number: 16
# Installed grass roll number: 17
# Installed grass roll number: 18
# Installed grass roll number: 19
# Installed grass roll number: 20
# Installed grass roll number: 21
# Installed grass roll number: 22
# Installed grass roll number: 23
# Installed grass roll number: 24
# Installed grass roll number: 25
# Installed grass roll number: 26
# Installed grass roll number: 27
# Installed grass roll number: 28
# Installed grass roll number: 29
# ...

# %%
count = 1
while count <=10:
    print("Received pallet:", count)
    count += 1
# Out:
# Received pallet: 1
# Received pallet: 2
# Received pallet: 3
# Received pallet: 4
# Received pallet: 5
# Received pallet: 6
# Received pallet: 7
# Received pallet: 8
# Received pallet: 9
# Received pallet: 10

# %%
grass_type = ""
while grass_type != "done":
    grass_type = input("Enter grass type (or type 'done' to stop): ")
    if grass_type != "done":
        print("Recorded grass type:", grass_type)
# Out:
# Recorded grass type: rose
# Recorded grass type: sunflower

# %%
cycle = 1
while cycle <= 5:
    print("Fertilizer cycle", cycle, "completed")
    cycle += 1
# Out:
# Fertilizer cycle 1 completed
# Fertilizer cycle 2 completed
# Fertilizer cycle 3 completed
# Fertilizer cycle 4 completed
# Fertilizer cycle 5 completed

# %%
area_cut = 0
while area_cut < 5000:
    print("Cut 1000 sqft, changing blades")
    area_cut += 1000
# Out:
# Cut 1000 sqft, changing blades
# Cut 1000 sqft, changing blades
# Cut 1000 sqft, changing blades
# Cut 1000 sqft, changing blades
# Cut 1000 sqft, changing blades

# %%
count = 1
while count <= 12:
    print("roll no.: ", count)
    count += 1
# Out:
# roll no.:  1
# roll no.:  2
# roll no.:  3
# roll no.:  4
# roll no.:  5
# roll no.:  6
# roll no.:  7
# roll no.:  8
# roll no.:  9
# roll no.:  10
# roll no.:  11
# roll no.:  12

# %%
count

# %%
jersey_name = str(input("input jersey club name"))
quantity = int(input("enter jersey quantity"))
jersey_size = int(input("enter your size"))

print(f"the customer is to be given {jersey_name} in {quantity} amount of size {jersey_size}.")
# Out:
# the customer is to be given fc barcelona jersey in 2 amount of size 32.

# %%
marks = int(input("enter your percentage(out of 100)"))
if marks >90:
    print("you are the best")
elif 70<= marks <=90:
    print("you are average")
else:
    print("improve yourself")
# Out:
# you are average

# %%
for i in range(1,10):
    print(f"the roll no. is {i}")
# Out:
# the roll no. is 1
# the roll no. is 2
# the roll no. is 3
# the roll no. is 4
# the roll no. is 5
# the roll no. is 6
# the roll no. is 7
# the roll no. is 8
# the roll no. is 9

# %%
count = 1
while count <= 9:
    print(f"batch no. {count}")
    count += 1
# Out:
# batch no. 1
# batch no. 2
# batch no. 3
# batch no. 4
# batch no. 5
# batch no. 6
# batch no. 7
# batch no. 8
# batch no. 9

# %%
s = "swarnava das"
print(s)
print(s[1])
# Out:
# swarnava das
# w

# %%
s = "swarnava das"
print(s)
print(len(s))
# Out:
# swarnava das
# 12

# %%
s = "swarnava das"
print(s)
print(s[1:8])
# Out:
# swarnava das
# warnava
