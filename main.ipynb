# %%
steps_to_reach_vaishno_devi = 7400
steps_completed = 4200
steps_remaining = steps_to_reach_vaishno_devi-steps_completed
print(f"the steps remaining are {steps_remaining}")
task 1
# Out:
# the steps remaining are 3200

# %%
price_for_visiting_akshardham_temple = 250
total_family_members = 4
total_ticket_cost = (price_for_visiting_akshardham_temple*total_family_members)
print(f"the total fare is {total_ticket_cost}")
Task 2
# Out:
# the total fare is 1000

# %%
donation_at_tirupati = 500
donation_at_shirdi = 300
total_donation = donation_at_tirupati + donation_at_shirdi
print(f"the total donation amount is {total_donation}") 
task 3
# Out:
# the total donation amount is 800

# %%
total_bells_in_kashi_viswanath_temple = 108
total_bells_in_somnath_temple = 92
total_bells = total_bells_in_kashi_viswanath_temple + total_bells_in_somnath_temple
print(f"the total number of bells is {total_bells}")
task4
# Out:
# the total number of bells is 200

# %%
height_jagannath_temple = 65
height_sun_temple = 70
combined_height = height_jagannath_temple + height_sun_temple
print(f"The combined height of Jagannath Temple and Sun Temple is: {combined_height} meters")
task5
# Out:
# The combined height of Jagannath Temple and Sun Temple is: 135 meters

# %%
offerings = 1200
food = 850
total_expenditure = offerings + food

# Using .format()
print("The total expenditure is: ₹{}".format(total_expenditure))

# Using f-string
print(f"The total expenditure is: ₹{total_expenditure}") 
task6
# Out:
# The total expenditure is: ₹2050
# The total expenditure is: ₹2050

# %%
collection1 = 250000
collection2 = 175000
total_collection = collection1 + collection2

# Way 1: Using f-strings
print(f"The total collection is: ₹{total_collection}")

# Way 2: Using the str.format() method
print("The total collection is: ₹{}".format(total_collection))

# Way 3: Using the % operator
print("The total collection is: ₹%d" % total_collection)

# Way 4: Using string concatenation
print("The total collection is: ₹" + str(total_collection))

# Way 5: Passing multiple arguments to the print function
print("The total collection is: ₹", total_collection)
task7
# Out:
# The total collection is: ₹425000
# The total collection is: ₹425000
# The total collection is: ₹425000
# The total collection is: ₹425000
# The total collection is: ₹ 425000

# %%
siddhivinayak_prasad = 99
ganpatipule_prasad = 151
total_spent = siddhivinayak_prasad + ganpatipule_prasad
print(f"The total amount spent on Prasad is: ₹{total_spent}")
task8
# Out:
# The total amount spent on Prasad is: ₹250

# %%
morning_wait_time = 35
evening_wait_time = 45
total_wait_time = morning_wait_time + evening_wait_time
print(f"The total wait time is: {total_wait_time} minutes")
task9
# Out:
# The total wait time is: 80 minutes

# %%
monday_pilgrims = 10520
tuesday_pilgrims = 12340
total_footfall = monday_pilgrims + tuesday_pilgrims
print(f"The total footfall at Rameswaram Temple was: {total_footfall}")
task10
# Out:
# The total footfall at Rameswaram Temple was: 22860

# %%
steps_at_palitana_jain_temple = 700
steps_at_chamundeshwari_temple = 320
total_steps = steps_at_palitana_jain_temple + steps_at_chamundeshwari_temple
print(f"the total steps climbed are {total_steps}")
task11
# Out:
# the total steps climbed are 1020

# %%
friend_donation = 1111
your_donation = 999
combined_donation = friend_donation + your_donation
print("The combined donation is: ₹" + str(combined_donation))
task12
# Out:
# The combined donation is: ₹2110

# %%
tea_cost = 15
snacks_cost = 25
total_cost = tea_cost + snacks_cost
print("The total refreshment cost is: ₹{}".format(total_cost))
task13
# Out:
# The total refreshment cost is: ₹40

# %%
rudraksha_mala_cost = 60
incense_sticks_cost = 80
total_cost = rudraksha_mala_cost + incense_sticks_cost
print("The total cost is: ₹", total_cost)
task14
# Out:
# The total cost is: ₹ 140

# %%
number_of_shrines = 5
priests_per_shrine = 3
total_priests = number_of_shrines * priests_per_shrine
print(total_priests)
task15
# Out:
# 15

# %%
coconuts_temple1 = 21
coconuts_temple2 = 11
total_coconuts = coconuts_temple1 + coconuts_temple2

# Way 1: Using f-strings
print(f"The total coconuts offered is: {total_coconuts}")

# Way 2: Using the str.format() method
print("The total coconuts offered is: {}".format(total_coconuts))

# Way 3: Using the % operator
print("The total coconuts offered is: %d" % total_coconuts)

# Way 4: Using string concatenation
print("The total coconuts offered is: " + str(total_coconuts))

# Way 5: Passing multiple arguments to the print function
print("The total coconuts offered is:", total_coconuts)
task16
# Out:
# The total coconuts offered is: 32
# The total coconuts offered is: 32
# The total coconuts offered is: 32
# The total coconuts offered is: 32
# The total coconuts offered is: 32

# %%
distance_to_temple = 7
round_trip_distance = distance_to_temple * 2
print(f"The round-trip distance is: {round_trip_distance} km")
task17
# Out:
# The round-trip distance is: 14 km

# %%
lights_at_kamakhya_temple = 108
lights_at_kalighat = 108
total_lamps_lit = lights_at_kamakhya_temple + lights_at_kalighat
print(f"total lamps lit are {total_lamps_lit}")
task18
# Out:
# total lamps lit are 216

# %%
donation_per_temple = 51
number_of_temples = 3
total_donation = donation_per_temple * number_of_temples
print("The total donation is: ₹" + str(total_donation))
task19
# Out:
# The total donation is: ₹153

# %%
hampi_souvenirs = 500
lepakshi_souvenirs = 250
combined_cost = hampi_souvenirs + lepakshi_souvenirs

# Using f-string
print(f"The combined souvenir cost is: ₹{combined_cost}")

# Using .format()
print("The combined souvenir cost is: ₹{}".format(combined_cost))
task20
# Out:
# The combined souvenir cost is: ₹750
# The combined souvenir cost is: ₹750
