# %%
# %pip install flask

# %%
from flask import Flask

app2 = Flask(__name__)

@app2.route("/")

def home():
    return "Hello, World!"

if __name__ == "__main__":
    app2.run(debug=False, port=5001)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5001
# Press CTRL+C to quit

# %%
from flask import Flask

app4 = Flask(__name__)

@app4.route("/")

def home():
    return "Hello, My name is Swarnava Das!!!"

if __name__ == "__main__":
    app4.run(debug=False, port=5003)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5003
# Press CTRL+C to quit
# 127.0.0.1 - - [27/Apr/2026 22:51:16] "GET / HTTP/1.1" 200 -

# %%
from flask import Flask

app3 = Flask(__name__)

@app3.route("/")

def home():
    return "Hello, My name is Swarnava Das!!!"

if __name__ == "__main__":
    app3.run(debug=False, port=5005)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5005
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Apr/2026 08:35:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2026 08:35:06] "GET /favicon.ico HTTP/1.1" 404 -

# %%
#flask web develpoment
#importing flask module
from flask import Flask

#creating the flask app
app6 = Flask(__name__)

#giving route and instance
@app6.route("/")
def home():
    return "Hello"

#running the web app
if __name__ == "__main__":
    app6.run(debug=False, port=5006)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5006
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Apr/2026 08:43:28] "GET / HTTP/1.1" 200 -

# %%
from flask import Flask 
app7 = Flask(__name__)
@app7.route("/")
def home():
    return "Hello, My name is Swarn!!!"
if __name__ =="__main__":
    app7.run(debug=False, port=5007)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5007
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Apr/2026 10:29:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2026 10:29:10] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from flask import Flask

app8 = Flask(__name__)

@app8.route("/")
def home():
    return "Hello, My name is Swarnava, age = 19!!!"
@app8.route("/about")
def about():
    app_about = "This is about page"
    return app_about
@app8.route("/data")
def data():
    app_data = "This is data page"
    return app_data


if __name__ == "__main__":
    app8.run(debug=False, port=5009)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5009
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Apr/2026 10:43:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2026 10:44:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2026 10:44:11] "GET /about HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2026 10:44:18] "GET /data HTTP/1.1" 200 -

# %%
from flask import Flask

app9 = Flask(__name__)

@app9.route("/")
def home():
    return "Hello, My name is Swarnava, age = 20!!!"
@app9.route("/about")   
def about():
    return "about page"
@app9.route("/data")
def data():
    return "data page"
@app9.route("/contact")
def contact():
    return "contact page"
@app9.route("/blog")
def blog():
    return "blog page"
if __name__ == "__main__":
    app9.run(debug=False, port=5010)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5010
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Apr/2026 10:51:57] "GET / HTTP/1.1" 200 -

# %%
from flask import Flask

app8 = Flask(__name__)

@app8.route("/")
def home():
    return "Hello, My name is Swarnava, age = 19!!!"
@app8.route("/about")
def about():
    app_about = """<h1>About Page</h1><br>
                    <h2>Welcome to the about page of our Flask application. Here you can find information about the purpose and features of this app.</h2>
                    <h3>thanks for visiting the about page!!!</h3>"""
    return app_about
@app8.route("/data")
def data():
    app_data = "This is data page"
    return app_data


if __name__ == "__main__":
    app8.run(debug=False, port=5010)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5010
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Apr/2026 10:57:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2026 10:58:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Apr/2026 10:58:17] "GET /about HTTP/1.1" 200 -

# %%
#get method in flask
from flask import Flask

app10 = Flask(__name__) 

@app10.route("/", methods=["GET"])
def home():
    return "Hello, My name is Swarnava!!"

if __name__ == "__main__":
    app10.run(debug=False, port=5011)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5011
# Press CTRL+C to quit
# 127.0.0.1 - - [29/Apr/2026 11:29:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/Apr/2026 11:29:43] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from flask import Flask

app11 = Flask(__name__)

@app11.route("/")
def home():
    return "Hello, My name is Swarnava Das!!!"
@app11.route("/about")
def about():
    app_about = """<h1>About Page</h1><br>
                    <h2>Welcome to the about page of our Flask application. Here you can find information about the purpose and features of this app.</h2>
                    <h3>thanks for visiting the about page!!!</h3>"""
    return app_about
@app11.route("/data")
def data():
    app_data = """<h1>Data Page</h1><br>
                    <h2>Welcome to the data page of our Flask application. Here you can find information about the data and statistics related to this app.</h2>
                    <h3>thanks for visiting the data page!!!</h3>"""
    return app_data

if __name__ == "__main__":
    app11.run(debug=False, port=5013)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5013
# Press CTRL+C to quit
# 127.0.0.1 - - [30/Apr/2026 08:47:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2026 08:47:00] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [30/Apr/2026 08:47:12] "GET /about HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2026 08:47:18] "GET /data HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2026 08:47:29] "GET /data HTTP/1.1" 200 -

# %%
from flask import Flask

app12 = Flask(__name__)

@app12.route("/", methods=["GET"])
def home():
    return "Hello, My name is Swarnava Das"

@app12.route("/contact", methods=["GET"])
def contact():
    return "Contact information goes here"

if __name__ == "__main__":
    app12.run(debug=False, port=5014)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5014
# Press CTRL+C to quit
# 127.0.0.1 - - [30/Apr/2026 08:55:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2026 08:55:51] "GET /contact HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Apr/2026 08:58:50] "GET / HTTP/1.1" 200 -

# %%
#handling json input in flask
API_KEY = "16fe1ec6122c49088cb49d432192f97a"

# %%
url = "https://newsapi.org/v2/everything?q=tesla&from=2026-03-29&sortBy=publishedAt&apiKey=16fe1ec6122c49088cb49d432192f97a"

# %%
import requests

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# {'status': 'ok',
#  'totalResults': 5904,
#  'articles': [{'source': {'id': 'globo', 'name': 'Globo'},
#    'author': None,
#    'title': 'Começa julgamento da OpenAI que coloca Elon Musk contra Sam Altman',
#    'description': 'Musk afirma que Altman e Greg Brockman o traíram e ao público ao abandonar a missão da empresa de ser uma guardiã benevolente da IA para o benefício da humanidade',
#    'url': 'https://valor.globo.com/empresas/noticia/2026/04/28/comea-julgamento-da-openai-que-coloca-elon-musk-contra-sam-altman.ghtml',
#    'urlToImage': 'https://s3.glbimg.com/v1/AUTH_63b422c2caee4269b8b34177e8876b93/public/fb_marca.png',
#    'publishedAt': '2026-04-28T11:47:45Z',
#    'content': 'Um julgamento que pode ajudar a moldar o futuro da inteligência artificial começa nesta terça-feira (28), com os bilionários Elon Musk e Sam Altman em desacordo sobre a evolução da OpenAI, criadora d… [+4080 chars]'},
#   {'source': {'id': 'globo', 'name': 'Globo'},
#    'author': None,
# ...

# %%
len(data["articles"])
# Out:
# 97

# %%
len(data["articles"][0])
# Out:
# 8

# %%
data["articles"][0].keys()
# Out:
# dict_keys(['source', 'author', 'title', 'description', 'url', 'urlToImage', 'publishedAt', 'content'])

# %%
first_article = data["articles"][0]
first_article
# Out:
# {'source': {'id': 'globo', 'name': 'Globo'},
#  'author': None,
#  'title': 'Começa julgamento da OpenAI que coloca Elon Musk contra Sam Altman',
#  'description': 'Musk afirma que Altman e Greg Brockman o traíram e ao público ao abandonar a missão da empresa de ser uma guardiã benevolente da IA para o benefício da humanidade',
#  'url': 'https://valor.globo.com/empresas/noticia/2026/04/28/comea-julgamento-da-openai-que-coloca-elon-musk-contra-sam-altman.ghtml',
#  'urlToImage': 'https://s3.glbimg.com/v1/AUTH_63b422c2caee4269b8b34177e8876b93/public/fb_marca.png',
#  'publishedAt': '2026-04-28T11:47:45Z',
#  'content': 'Um julgamento que pode ajudar a moldar o futuro da inteligência artificial começa nesta terça-feira (28), com os bilionários Elon Musk e Sam Altman em desacordo sobre a evolução da OpenAI, criadora d… [+4080 chars]'}

# %%
first_article["title"]
# Out:
# 'Começa julgamento da OpenAI que coloca Elon Musk contra Sam Altman'

# %%
first_article["author"]

# %%
first_article = data["articles"][0]
first_article["publishedAt"]
# Out:
# '2026-04-28T11:47:45Z'

# %%
output_data = {"article": "anything",
               "author": "ME"}
output_data
# Out:
# {'article': 'anything', 'author': 'ME'}
