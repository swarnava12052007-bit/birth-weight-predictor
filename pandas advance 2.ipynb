# %%
import pandas as pd

# %%
df = pd.read_csv("services.csv")
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df[0:10]
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
# 5   6            6         NaN               NaN            NaN
# 6   7            7         NaN               NaN            NaN
# 7   8            8         NaN               NaN            NaN
# 8   9            9         NaN               NaN            NaN
# 9  10           10         NaN               NaN            NaN
#
#                                  application_process  \
# 0                         Walk in or apply by phone.
# 1                 Apply by phone for an appointment.
# 2        Phone for information (403-4300 Ext. 4322).
# ...

# %%
df[0:10:3]
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 6   7            7         NaN               NaN            NaN
# 9  10           10         NaN               NaN            NaN
#
#                                  application_process  \
# 0                         Walk in or apply by phone.
# 3                                    Apply by phone.
# 6  Apply by phone or be referred by a doctor, soc...
# 9  Walk in. Proof of California residency to rece...
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 3  Parents, children, families with problems of c...
# 6  Older adults who have memory or sensory loss, ...
# 9                                                NaN
#
#                                          description  \
# ...

# %%
df[0:10:2]
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
# 6   7            7         NaN               NaN            NaN
# 8   9            9         NaN               NaN            NaN
#
#                                  application_process  \
# 0                         Walk in or apply by phone.
# 2        Phone for information (403-4300 Ext. 4322).
# 4                             Phone for information.
# 6  Apply by phone or be referred by a doctor, soc...
# 8  Walk in. Proof of residency in California requ...
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 2  Older adults age 55 or over who can benefit fr...
# 4  Low-income working families with children tran...
# ...

# %%
df.iloc[0:10]
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
# 5   6            6         NaN               NaN            NaN
# 6   7            7         NaN               NaN            NaN
# 7   8            8         NaN               NaN            NaN
# 8   9            9         NaN               NaN            NaN
# 9  10           10         NaN               NaN            NaN
#
#                                  application_process  \
# 0                         Walk in or apply by phone.
# 1                 Apply by phone for an appointment.
# 2        Phone for information (403-4300 Ext. 4322).
# ...

# %%
df.loc[0:10]
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 0    1            1         NaN               NaN            NaN
# 1    2            2         NaN               NaN            NaN
# 2    3            3         NaN               NaN            NaN
# 3    4            4         NaN               NaN            NaN
# 4    5            5         NaN               NaN            NaN
# 5    6            6         NaN               NaN            NaN
# 6    7            7         NaN               NaN            NaN
# 7    8            8         NaN               NaN            NaN
# 8    9            9         NaN               NaN            NaN
# 9   10           10         NaN               NaN            NaN
# 10  11           11         NaN               NaN            NaN
#
#                                   application_process  \
# 0                          Walk in or apply by phone.
# 1                  Apply by phone for an appointment.
# ...

# %%
df.iloc[0:3, 0:6]
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).

# %%
import pandas as pd

# %%
df = pd.read_csv("services.csv")
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.iloc[0:10, 0:6]
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
# 5   6            6         NaN               NaN            NaN
# 6   7            7         NaN               NaN            NaN
# 7   8            8         NaN               NaN            NaN
# 8   9            9         NaN               NaN            NaN
# 9  10           10         NaN               NaN            NaN
#
#                                  application_process
# 0                         Walk in or apply by phone.
# 1                 Apply by phone for an appointment.
# 2        Phone for information (403-4300 Ext. 4322).
# ...

# %%
list[df["alternate_name"][0:10]]
# Out:
# list[0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: alternate_name, dtype: str]

# %%
#to make it in series
s1 = pd.Series(list(df["alternate_name"][2:5]), index = ['a','b','c'])
s1
# Out:
# a   NaN
# b   NaN
# c   NaN
# dtype: float64

# %%
s2 = pd.Series(list(df["alternate_name"][6:9]))
s2
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# dtype: float64

# %%
s1 + s2
# Out:
# a   NaN
# b   NaN
# c   NaN
# 0   NaN
# 1   NaN
# 2   NaN
# dtype: float64

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
n = df.drop('id', axis = 1)
n
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 n = df.drop('id', axis = 1)
#       2 n
#
# File c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
# ...

# %%
df = pd.read_csv("services.csv")
n = df.drop('id', axis=1)
n
# Out:
#     location_id  program_id         accepted_payments         alternate_name  \
# 0             1         NaN                       NaN                    NaN
# 1             2         NaN                       NaN                    NaN
# 2             3         NaN                       NaN                    NaN
# 3             4         NaN                       NaN                    NaN
# 4             5         NaN                       NaN                    NaN
# 5             6         NaN                       NaN                    NaN
# 6             7         NaN                       NaN                    NaN
# 7             8         NaN                       NaN                    NaN
# 8             9         NaN                       NaN                    NaN
# 9            10         NaN                       NaN                    NaN
# 10           11         NaN                       NaN                    NaN
# ...

# %%
df = pd.read_csv("services.csv")
m = df.drop(1)
m
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# 15  16           16         NaN                       NaN
# ...

# %%
df.set_index('program_id', inplace=True)
df
# Out:
#             location_id         accepted_payments         alternate_name  \
# program_id
# NaN                   1                       NaN                    NaN
# NaN                   2                       NaN                    NaN
# NaN                   3                       NaN                    NaN
# NaN                   4                       NaN                    NaN
# NaN                   5                       NaN                    NaN
# NaN                   6                       NaN                    NaN
# NaN                   7                       NaN                    NaN
# NaN                   8                       NaN                    NaN
# NaN                   9                       NaN                    NaN
# NaN                  10                       NaN                    NaN
# NaN                  11                       NaN                    NaN
# NaN                  12                       NaN                    NaN
# ...

# %%
df.reset_index()
# Out:
#     program_id  location_id         accepted_payments         alternate_name  \
# 0          NaN            1                       NaN                    NaN
# 1          NaN            2                       NaN                    NaN
# 2          NaN            3                       NaN                    NaN
# 3          NaN            4                       NaN                    NaN
# 4          NaN            5                       NaN                    NaN
# 5          NaN            6                       NaN                    NaN
# 6          NaN            7                       NaN                    NaN
# 7          NaN            8                       NaN                    NaN
# 8          NaN            9                       NaN                    NaN
# 9          NaN           10                       NaN                    NaN
# 10         NaN           11                       NaN                    NaN
# ...

# %%
d = {'key1': [2, 3, 4],
    'key2':[5, 6, 7],
    'key3': [8, 9, 10]}
d
# Out:
# {'key1': [2, 3, 4], 'key2': [5, 6, 7], 'key3': [8, 9, 10]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     5     8
# 1     3     6     9
# 2     4     7    10

# %%
df1 = pd.read_csv("taxonomy.csv")
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna("missing")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency   missing               missing
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data1 = {'A': [1, 2, None, 4, 5, None, 7, 8, 9, 10],
         'B': [None, 11, 12, 13, None, 15, 16, None, 18, 19]}

data2 = pd.DataFrame(data1)
data2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.ffill()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]
