# %%
#dictionary
my_dict = { "name": "Alice",
            "age": 30,
            "city": "New York"}
   

print(my_dict)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
#dictionary fundamentals and syntax 

#task 1 
ikea_parcel = {"package_id": "IKEA-B2B-PKG-001",
                "origin_fc": "FC_GOT",
                "destination_store": "STORE_STHLM",
                 "weight_kg": 15.5,
                 "dimensions_cm": "100x60x40",
                 "priority_flag": True }

print("task 1 =", ikea_parcel)

#task 2
customer_profile = {"customer_id": "IKEA-0012",
                    "company_name": "Fortis hospitals",
                    "segment (“Hospitality”, “Office”, etc.)": "Hospitality",
                    "gstin/vat": "0012345",
                    "credit_limit": "₹25000",
                    "delivery_terms": "DAP"}

print("task 2 =", customer_profile)

#task 3
machine_sensor = {"machine_id": "001298 Hitachi",
                  "timestamp": "2017",
                  "temperature_c": "37-39 degrees",
                  "vibration_mm_s": "126-130",
                  "throughput_cph": "950.50"}

print("task 3 =", machine_sensor)
# Out:
# task 1 = {'package_id': 'IKEA-B2B-PKG-001', 'origin_fc': 'FC_GOT', 'destination_store': 'STORE_STHLM', 'weight_kg': 15.5, 'dimensions_cm': '100x60x40', 'priority_flag': True}
# task 2 = {'customer_id': 'IKEA-0012', 'company_name': 'Fortis hospitals', 'segment (“Hospitality”, “Office”, etc.)': 'Hospitality', 'gstin/vat': '0012345', 'credit_limit': '₹25000', 'delivery_terms': 'DAP'}
# task 3 = {'machine_id': '001298 Hitachi', 'timestamp': '2017', 'temperature_c': '37-39 degrees', 'vibration_mm_s': '126-130', 'throughput_cph': '950.50'}

# %%
#dictionary rules (keys/values/orders)

#task 4
dup_key_demo = {"P001": "ALEX", "P002": "MARKUS", "P001": "LINNMON"}
print("Task 4 = ", dup_key_demo)

#task 5
dept_sla = {"DC": "48h", "STORES": "48h", "ONLINE": "24h", "B2B": "48h"}
print("Task 5:", dept_sla)

#task 6
order_header = {}
order_header["order_id"] = "SO-80012"
order_header["customer_id"] = "B2B-ACME-4401"
order_header["order_date"] = "2025-08-15"
order_header["currency"] = "INR"
print("Task 6: key iteration in insertion order:", list(order_header.keys()))
# Out:
# Task 4 =  {'P001': 'LINNMON', 'P002': 'MARKUS'}
# Task 5: {'DC': '48h', 'STORES': '48h', 'ONLINE': '24h', 'B2B': '48h'}
# Task 6: key iteration in insertion order: ['order_id', 'customer_id', 'order_date', 'currency']

# %%
#real-world use case

#task 7
customer = {"id": "B2B-ACME-4401",
            "name": "ACME Hospitality Pvt Ltd",

    "addresses": { "billing": {"line1": "12 Park St", "city": "Mumbai", "zip": "400001"},
                   "shipping": {"line1": "Dockyard Rd", "city": "Mumbai", "zip": "400010"}},

    "contacts": [{"name": "Riya Sen", "email": "riya.sen@acme.com", "role": "Procurement"},
                 {"name": "V. Kumar", "email": "vkumar@acme.com", "role": "Finance"}]}

print("Task 7 (shipping city before):", customer["addresses"]["shipping"]["city"])
print("Task 7 (first contact):", customer["contacts"][1])

#task 8 
inventory = {"LINNMON": {"name": "LINNMON Tabletop", "qty": 140, "price_inr": 2490, "reorder_level": 60, "category": "Table"},
             "ALEX": {"name": "ALEX Drawer Unit", "qty": 30, "price_inr": 9990, "reorder_level": 40, "category": "Storage"},
             "MARKUS": {"name": "MARKUS Office Chair", "qty": 18, "price_inr": 19990, "reorder_level": 25, "category": "Office Chair"},
             "BEKANT": {"name": "BEKANT Desk", "qty": 65, "price_inr": 15990, "reorder_level": 50, "category": "Desk"},
             "TROFAST": {"name": "TROFAST Frame", "qty": 45, "price_inr": 3500, "reorder_level": 30, "category": "Storage"}}

print("Task 8 (inventory sample):", inventory["ALEX"])
 
#task 9
sensor_event = {"zone": "ASRS-Aisle-03",
                "last_metrics": {"temp_c": 29.4, "humidity_pct": 53.0, "latency_ms": 88},
                "alerts": ["Low battery on shuttle-2", "Barcode misread on bay-5", "Overheat on lift-1"]}

sensor_event["alerts"].append("Vision occlusion on bay-2")
sensor_event["alerts"].pop(0)  

print("Task 9 (alerts trimmed to last 3):", sensor_event["alerts"])


print("\n=== SECTION D: Dictionary Creation Methods ===")
# Out:
# Task 7 (shipping city before): Mumbai
# Task 7 (first contact): {'name': 'V. Kumar', 'email': 'vkumar@acme.com', 'role': 'Finance'}
# Task 8 (inventory sample): {'name': 'ALEX Drawer Unit', 'qty': 30, 'price_inr': 9990, 'reorder_level': 40, 'category': 'Storage'}
# Task 9 (alerts trimmed to last 3): ['Barcode misread on bay-5', 'Overheat on lift-1', 'Vision occlusion on bay-2']
#
# === SECTION D: Dictionary Creation Methods ===

# %%
#dictionary creation methods

#task 10(literal method)
employee = {"id": "EMP-440", "name": "Shweta", "dept": "DC-Operations", "shift": "A", "salary": 540000}
print("Task 10:", employee)

#task 11(dict constructor)
product = dict(name="BEKANT desk", price=15990, stock=120, uom="pcs")
print("Task 11:", product)

#task 12(from list of tuples)
tpls = [("id", "0012"), ("name", "swarnava das")]
product_from_tpls = dict(tpls) 
print("Task 12:", product_from_tpls)

#task 13(zip two lists)
keys = ["id", "name"]
value = ["0012", "Swarnava Das"]
items = dict(zip(keys, value))
print("Task 13:", items)

#task 14(from nested data: list of tuples)
tuples_qty = [("LINNMON", 140), ("ALEX", 30), ("MARKUS", 18)]
on_hand = dict(tuples_qty)
print("Task 14:", on_hand)

#task 15(JSON-like structure validity)
bulk_order = {"header": {"order_id": "SO-90071",
                         "customer_id": "B2B-ACME-4401",
                         "segment": "Hospitality"},

    "lines": [{"sku": "MARKUS", "qty": 6, "unit_price": 19990},
              {"sku": "BEKANT", "qty": 12, "unit_price": 15990},
              {"sku": "LINNMON", "qty": 20, "unit_price": 2490}]}

print("Task 15 (top-level keys):", list(bulk_order.keys()))


print("\n=== SECTION E: Accessing, Reading, Iteration ===")
# Out:
# Task 10: {'id': 'EMP-440', 'name': 'Shweta', 'dept': 'DC-Operations', 'shift': 'A', 'salary': 540000}
# Task 11: {'name': 'BEKANT desk', 'price': 15990, 'stock': 120, 'uom': 'pcs'}
# Task 12: {'id': '0012', 'name': 'swarnava das'}
# Task 13: {'id': '0012', 'name': 'Swarnava Das'}
# Task 14: {'LINNMON': 140, 'ALEX': 30, 'MARKUS': 18}
# Task 15 (top-level keys): ['header', 'lines']
#
# === SECTION E: Accessing, Reading, Iteration ===

# %%
#updating, adding and merging

#task 16
contract_sku = {"sku": "MARKUS", "discount": 5}
pricing_overrides = {"discount": 12, "promo_code": "CORP-AUG"}
contract_sku.update(pricing_overrides)
print("Task 16 (merged update):", contract_sku)

#task 17
customer_profile = {"customer_id": "C67890","company": "Acme Corp"}
customer_profile["contract_terms"] = "NET45"
customer_profile["credit_limit"] = 1200000
print("Task 17:", customer_profile)

#task 18
product = {"product_id": "FAN-ATB-RENESA","name": "Atomberg Renesa+","price": 3500}
product["sustainability_score"] = {"recycled_material_pct": 15,"packaging_eco_grade": "A"}

print("Task 18:", product)
# Out:
# Task 16 (merged update): {'sku': 'MARKUS', 'discount': 12, 'promo_code': 'CORP-AUG'}
# Task 17: {'customer_id': 'C67890', 'company': 'Acme Corp', 'contract_terms': 'NET45', 'credit_limit': 1200000}
# Task 18: {'product_id': 'FAN-ATB-RENESA', 'name': 'Atomberg Renesa+', 'price': 3500, 'sustainability_score': {'recycled_material_pct': 15, 'packaging_eco_grade': 'A'}}

# %%
#removing data

#task 19
package = {"priority_flag": "10000", "id": "0012" }
if "priority_flag" in package:
    del package["priority_flag"]
print("Task 19 (priority_flag removed if existed):", package)

#task 20
customer = {"customer_id": "C67890", "company": "Acme Corp", "dnd_flag": "True"}
removed = customer.pop("dnd_flag", "Not Found")
print("Task 20 ", removed)

#task 21
product = {"id": "0012", "year": "2025"}
last_item = product.popitem()
print("Task (popitem):", last_item)

#task 22
scratchpad = {"temp": 1, "work": "in-progress"}
scratchpad.clear()
print("Task 22 (scratchpad cleared):", scratchpad)
# Out:
# Task 19 (priority_flag removed if existed): {'id': '0012'}
# Task 20  True
# Task (popitem): ('year', '2025')
# Task 22 (scratchpad cleared): {}

# %%
#copying and references

# Original dictionary
original_dict = {'name': 'Alice', 'age': 30, 'details': {'city': 'New York'}}

# Creating a reference
referenced_dict = original_dict

# Modifying through the referenced dictionary
referenced_dict['age'] = 31
referenced_dict['details']['city'] = 'London'

print(f"Original after reference modification: {original_dict}")
print(f"Referenced dictionary: {referenced_dict}")
# Out:
# Original after reference modification: {'name': 'Alice', 'age': 31, 'details': {'city': 'London'}}
# Referenced dictionary: {'name': 'Alice', 'age': 31, 'details': {'city': 'London'}}

# %%
#input user

user_input = "{'vendor':'VND-778','lead_time_days':7,'payment':'NEFT'}"
safe_dict = ast.literal_eval(user_input)(clear_output())
print("Task 31 (safe parsed):", safe_dict, type(safe_dict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 #input user
#       3 user_input = "{'vendor':'VND-778','lead_time_days':7,'payment':'NEFT'}"
# ----> 4 safe_dict = ast.literal_eval(user_input)(clera())
#       5 print("Task 31 (safe parsed):", safe_dict, type(safe_dict))
#
# NameError: name 'ast' is not defined

# %%
aim = ("student marks")
marks = ("student marks")
number = ("student average")
marks = ("average number")
print(f"getting(student marks)") 
the_complete_course = "the complete marks"
# Out:
# getting(student marks)
